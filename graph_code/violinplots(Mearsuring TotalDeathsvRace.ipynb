# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import seaborn as sns
data1 = pd.read_csv("sDeaths2019_count.csv")
data1.head()
# Out:
#    Death Date  Age  Race  Gender  tsuicides_2019
# 0  2019-01-02   22     1       0               1
# 1  2019-01-02   66     0       0               2
# 2  2019-01-06   84     2       0               3
# 3  2019-01-07   66     0       0               4
# 4  2019-01-14   60     0       0               5

# %%
data2 = pd.read_csv("sDeaths2019_count.csv")
age = data2.Age
race = data2.Race
gender = data2.Gender
deaths = data2.tsuicides_2019
sns.violinplot(x=race,y=deaths,data =data2, )
plt.savefig('violinplot1(2019)(RVT).png')
plt.show()

# %%
data2 = pd.read_csv("sDeaths2020_count.csv")
data2.head()
# Out:
#    Unnamed: 0  Age  Race  Gender  Total_cases  tsuicides_2020
# 0  2020-02-01   25     1       1            6               1
# 1  2020-02-02   36     0       0            6               2
# 2  2020-02-04   72     0       0            6               3
# 3  2020-02-06   41     3       0            6               4
# 4  2020-02-07   58     0       1            6               5

# %%
data2 = pd.read_csv("sDeaths2020_count.csv")
age = data2.Age
race = data2.Race
gender = data2.Gender
deaths = data2.tsuicides_2020
sns.violinplot(x=race,y=deaths,data =data2, )
plt.savefig('violinplot1(2020)(RVT).png')
plt.show()
