# %%
import pandas as pd
import numpy
import matplotlib.pyplot as plt

import seaborn as sns
data1 = pd.read_csv("sDeaths2019.csv")

data1.head()
# Out:
#    Death Date  Age  Race  Gender
# 0  2019-01-02   22     1       0
# 1  2019-01-02   66     0       0
# 2  2019-01-06   84     2       0
# 3  2019-01-07   66     0       0
# 4  2019-01-14   60     0       0

# %%
age = data1.Age
race = data1.Race
gender = data1.Gender
sns.violinplot(x=race,y=gender,data =data1)
plt.show()

# %%
data2 = pd.read_csv("sDeaths2020.csv")
age = data2.Age
race = data2.Race
gender = data2.Gender
sns.violinplot(x=race,y=gender,data =data2, )
plt.show()





sns.violinplot(x=gender,y=race,data =data1,cut = 0 )
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Race'>
